# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd 
import time 
import pprint
import sys
import math
import spotipy
import spotipy.util as util

SPOTIPY_CLIENT_ID='beb55c03e9d647e6ac01fe69751c1067'
SPOTIPY_CLIENT_SECRET='2957070a9a0a4d75a92e6091cd67dfd2'
SPOTIPY_REDIRECT_URI='http://localhost:8888'

errorlog = open('errorlog.txt','w')
lineupfile = open('list_ids.txt','r')
lineup = [x.strip('\n') for x in lineupfile.readlines()]

numberofbands = len(lineup)
tracks = []

USERNAME = '1262504911'

# %%
sp = spotipy.Spotify(auth=token)

# %%
# token

# %%
import configparser

import spotipy
import spotipy.oauth2 as oauth2

config = configparser.ConfigParser()
config.read('config.cfg')
client_id = config.get('SPOTIFY', 'CLIENT_ID')
client_secret = config.get('SPOTIFY', 'CLIENT_SECRET')


auth = oauth2.SpotifyClientCredentials(
    client_id=client_id,
    client_secret=client_secret
)

# token = auth.get_access_token()
token = util.prompt_for_user_token(username=USERNAME, scope = 'playlist-modify user-read-private' , client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET, redirect_uri=SPOTIPY_REDIRECT_URI)
spotify = spotipy.Spotify(auth=token)

# %%
if len(sys.argv) > 2:
    username = '1262504911'
    playlist_id ='1kIWAmjxOhvgmdZmbp1RiH'
else:
    print("Usage: %s username playlist_id ..." % (sys.argv[0],))
    sys.exit()
index = 0
scope = 'user-follow-modify playlist-modify-public'
token = token

    # username = '1262504911'
    # playlist_id = '2YZHhiGjh6diaIxHDK3Mo7' spotify:playlist:2YZHhiGjh6diaIxHDK3Mo7

# %%
input_bands = list(set(lineup)) # removes dups
songs_per = 5
playlist_id = playlist_id

# %%
#GET RID OF THIS ONCE SOLVE ISSUE

# %%
token
# Out:
# 'BQAajtI4KUZdUvLlQd-uNGsxSlJaTHQJy9WebJznA-d6JCuhsMKpKxbG95AZAPjYA0zdQ-kO9V2AGilh_BcSELxLrLjliy4h6EhzyscnGIwLtummqD1riDCQU4xsSrhxYMGzIEDde4lmOZAt3zhS6o0lcMyH9DGyr32lRwElzni0SHXBpG6EbQVBdYnyH5zSAM5tVs0'

# %%
lineupfile = open('list_ids.txt','r')
lineup = [x.strip('\n') for x in lineupfile.readlines()]

df_ids = pd.read_csv('ids_scraped.csv')
df_ids.head(5)
# Out:
#    Unnamed: 0                                            spotify  \
# 0           0  https://open.spotify.com/artist/7GT8mZHoTsRGMk...
# 1           1  https://open.spotify.com/artist/2VfhnjHV7e3M49...
# 2           2  https://open.spotify.com/artist/0DJJrg8eUagEWZ...
# 3           3  https://open.spotify.com/artist/3KQoZQIHTfe9Fs...
# 4           4  https://open.spotify.com/artist/4bnCmwKU89Rt1z...
#
#                        id
# 0   GT8mZHoTsRGMkmownzCeo
# 1  VfhnjHV7e3M499VPa1w71?
# 2   DJJrg8eUagEWZXFgwKJfM
# 3  KQoZQIHTfe9FsMMRuw9S6?
# 4  bnCmwKU89Rt1zWnRIdSUa?

# %%
ids_list = df_ids['id'].tolist()
joinedlist = lineup + ids_list
# joinedlist

# %%
input_bands = list(set(joinedlist)) # removes dups
songs_per = 5
playlist_id = playlist_id

# %%
sp = spotipy.Spotify(auth=token)

# %%
input_bands = [x for x in input_bands if str(x) != 'nan']

# %%
# input_bands

# %%
album_names = []
album_uris = []
# for x in range(0,len(input_bands)):
for (i, item) in enumerate(input_bands):
    try:
        sp_albums = sp.artist_albums(item, album_type='album')
        #Store artist's albums' names' and uris in separate lists
        for i in range(len(sp_albums['items'])):
            album_names.append(sp_albums['items'][i]['name'])
            album_uris.append(sp_albums['items'][i]['uri'])
        print("cool")
    except:
        print("nah")
# Out:
# rned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/mxWFElGWogIysZsTFUNM9?/albums returned 400 due to invalid id
# nah
# cool
# nah
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/w6Xt64BqW4uUnWFIjOaxz/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/bfb0l7VxpKd0GjnQfg1oM?/albums returned 400 due to invalid id
# cool
# nah
# cool
# nah
# HTTP Error for GET to https://api.spotify.com/v1/artists/MKB5HGt7ZcprzEZt4BxMV?/albums returned 400 due to invalid id
# cool
# cool
# nah
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/TkCrIZnyUs5vQpj1J15uZ//albums returned 404 due to error
# HTTP Error for GET to https://api.spotify.com/v1/artists/Ob9XDKBMpR5BcIqS9uDwm?/albums returned 400 due to invalid id
# cool
# nah
# cool
# nah
# HTTP Error for GET to https://api.spotify.com/v1/artists/HVBwyBsglfpIgDNqcMEjA/albums returned 400 due to invalid id
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/q7Td1MO6rNg3UCvqrzz1k?/albums returned 400 due to invalid id
# nah
# cool
# cool
# nah
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/PqW14GmSWgnBZz8zrxdZA?/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/sy64aSFjVqCBsLFXVSTU6?/albums returned 400 due to invalid id
# cool
# cool
# nah
# nah
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/ZLr3aKQ4lVQeM4OOa5Ela?/albums returned 400 due to invalid id
# cool
# cool
# cool
# nah
# HTTP Error for GET to https://api.spotify.com/v1/artists/ryXEAhCtpAAkbBvzWfbcu?/albums returned 400 due to invalid id
# cool
# nah
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/raachkXWwcBhV1mB1JqEp?/albums returned 400 due to invalid id
# nah
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/iSrM548FTdDmoQL4tM25C?/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/wbEhjeRA7vQV9YnCLTYM6/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/bnCmwKU89Rt1zWnRIdSUa?/albums returned 400 due to invalid id
# nah
# cool
# nah
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/xK1FKfOekcpygF2EKy232?/albums returned 400 due to invalid id
# nah
# nah
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/PYQr0aueD4A0aTaBHb5q/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/aPeCAQ5XK9CLy0xmI0jzo?/albums returned 400 due to invalid id
# cool
# cool
# nah
# nah
# HTTP Error for GET to https://api.spotify.com/v1/artists/SicSle6DTMzk5Wqe1XHma/albums returned 400 due to invalid id
# cool
# nah
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/eeVbKWymAo1oPIxjbmnWD?/albums returned 400 due to invalid id
# cool
# nah
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/NA7pdIdD5hjZMMxI85CAX?/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/DKVFS18y79KMlPHbYxjuM/albums returned 400 due to invalid id
# nah
# cool
# nah
# cool
# cool
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/wo8vS76RmX26FS40DgZWL?/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/w1LZ5yv17OuqllP6vUDNp/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/LVhFKwUlU1LuYlXgVAID/albums returned 400 due to invalid id
# nah
# cool
# nah
# nah
# cool
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/x5XHrsSJJd7jqzbUVJvRD/albums returned 400 due to invalid id
# cool
# cool
# nah
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/fv3kezOH5l5v6IVMjUz8/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/PivAiOSXz8Wq4Q3kttr06/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/G6TE31NnbAVQEa2fy5l2S/albums returned 400 due to invalid id
# nah
# cool
# nah
# nah
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/BCaMwNAH4g210IpToQ4Mi/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/Vr7EHw03mdYI8NOLPj1pR/albums returned 400 due to invalid id
# nah
# nah
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/8nxqKPALx9UWm2IKBh16C?/albums returned 400 due to invalid id
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/4LiPbPOPaFCIcxdnnHY6G/albums returned 400 due to invalid id
# nah
# cool
# nah
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/9T0gHyu45Wa4fbsy9TppZ/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/iW8bv3aUP8Dte1KnMBH8c/albums returned 400 due to invalid id
# cool
# nah
# cool
# cool
# nah
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/vyj5BkUzgvcSf3RJZLEDK#/albums returned 400 due to invalid id
# cool
# cool
# nah
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/XA55ngSJ103aClybeiMvH?/albums returned 400 due to invalid id
# nah
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/elMzGj4El7Ej88zUzTF8P?/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/oH9QnmcbZ9q3aAUgO1OEH/albums returned 400 due to invalid id
# cool
# nah
# cool
# nah
# HTTP Error for GET to https://api.spotify.com/v1/artists/TnNCmSJSzsQIrbtwnllAl?/albums returned 400 due to invalid id
# cool
# nah
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/kubwrCcS0BlAq6b9TCn7T/albums returned 400 due to invalid id
# cool
# nah
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/DUdv5cMsW42EhpMKctQie/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/00cUpGQXb55bpwLMC8F5?s/albums returned 400 due to invalid id
# nah
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/iVp3oRGRXO9LL5E5NkLD/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/khKmbMt4afVHGG419NPVL/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/oVqqRdsT3EFQN0DPuFZ93?/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/7ON1uqBgUZVPOB6suCTxM/albums returned 400 due to invalid id
# nah
# nah
# nah
# cool
# nah
# nah
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists
albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/y1oX1cdYefr4vGoU4lUKc/albums returned 400 due to invalid id
# nah
# cool
# cool
# nah
# HTTP Error for GET to https://api.spotify.com/v1/artists/8GjSujfaeKjszBjxUj3JH/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/KQoZQIHTfe9FsMMRuw9S6?/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/55G3GjsOw5ckSlEdr5U1N?/albums returned 400 due to invalid id
# nah
# nah
# cool
# nah
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/N38mQmUdpz0R9gz1Iinb?n/albums returned 400 due to invalid id
# nah
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/gxeEjuyxsVd1lZZVzB8Kj?/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/zfgwutKN5osiOsQUyoOGR/albums returned 400 due to invalid id
# cool
# cool
# nah
# nah
# HTTP Error for GET to https://api.spotify.com/v1/artists/C7tCTiTzP4ah8MdN86go/albums returned 400 due to invalid id
# cool
# nah
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/FTTaB44zSMyg8OlHmiJAr?/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/1zcypuiPtwHcEJsXC0S1X?/albums returned 400 due to invalid id
# cool
# cool
# nah
# nah
# HTTP Error for GET to https://api.spotify.com/v1/artists/cN9JUcmWKhbR3kM2mWIge?/albums returned 400 due to invalid id
# cool
# cool
# nah
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/2cA1yK5H7nryrrEeiuU5t/albums returned 400 due to invalid id
# cool
# cool
# cool
# nah
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/hGAmenotnXWWu3yU3bRn/albums returned 400 due to invalid id
# nah
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/Ssvxfw2kfG1jkfDJDGJoh?/albums returned 400 due to invalid id
# nah
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/UHrpFMKe6tF5EMac2p4H3?/albums returned 400 due to invalid id
# cool
# nah
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/pGh7fFYv6WHlLU8y8j5eV?/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/SUZ0oubt3BD3RDDlzj1Vg?/albums returned 400 due to invalid id
# cool
# nah
# nah
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/LlMmpB3oWMxDz1Z6VOsNL/albums returned 400 due to invalid id
# cool
# nah
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/y2SzdrexQoN4X8CkW3k5E/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/hT5LWYkamZez1vAymMJeD/albums returned 400 due to invalid id
# nah
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/qU5Ef2aCV7kC57rIoZSm4?/albums returned 400 due to invalid id
# nah
# nah
# cool
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/VTXcLJ0rLBYFYaJ3S6QKX?/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/hn6t7JThJyefAHXLqdjjD?/albums returned 400 due to invalid id
# cool
# nah
# cool
# nah
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/ZLIaLRM2s4xbWISkJpiIt?/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/7f2kQ5Os8TFpqvnoDjMDp?/albums returned 400 due to invalid id
# cool
# nah
# cool
# nah
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/GtkmEc6QTw846GzvriDw?s/albums returned 400 due to invalid id
# cool
# cool
# cool
# nah
# HTTP Error for GET to https://api.spotify.com/v1/artists/6khwozOluH0ZMNgQpj0q?s/albums returned 400 due to invalid id
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/2xhtoW2mcljZdKY1psA6M?/albums returned 400 due to invalid id
# nah
# cool
# nah
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/NfSLIcuwffd82BgIEaSJ0/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/bfb0l7VxpKd0GjnQfg1oM/albums returned 400 due to invalid id
# cool
# nah
# nah
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/WxQ2B0qsEZ4Dh8rNGIp28?/albums returned 400 due to invalid id
# nah
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/lYyeQL2uuU7Q4cQeWEmqr?/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/kSguFGxxd8tlMAgzQyy0g/albums returned 400 due to invalid id
# nah
# nah
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/xAgoMa2YgjeZ54SiGGChW/albums returned 400 due to invalid id
# cool
# nah
# cool
# cool
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/esults/Erin%20Coburn/albums returned 404 due to error
# HTTP Error for GET to https://api.spotify.com/v1/artists/nZB3kXTQyI0wkblWgJk4/albums returned 400 due to invalid id
# cool
# cool
# nah
# nah
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/LWda5NiAvp94bjzzcBwYy/albums returned 400 due to invalid id
# cool
# cool
# cool
# nah
# HTTP Error for GET to https://api.spotify.com/v1/artists/QCdII4rQLJur2HHhE1EQ/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/DP6uwILXGWx4Z64e4918V?/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/7VTTs4IOPMNUiClgBg27D/albums returned 400 due to invalid id
# HTTP Error for GET to https://api.spotify.com/v1/artists/LzUup4s2ijIPOy5K4FlHC/albums returned 400 due to invalid id
# nah
# nah
# nah
# nah
# cool
# cool
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/MN0nrqrLC9tdFRGEK5qM/albums returned 400 due to invalid id
# cool
# nah
# cool
# cool
# HTTP Error for GET to https://api.spotify.com/v1/artists/gFSPXUc6QHkMd1WR0JC7a/albums returned 400 due to invalid id
# cool
# cool
# nah
# HTTP Error for GET to https://api.spotify.com/v1/artists/yucL0DfaASuZuJEd7fgu?h/albums returned 400 due to invalid id
# cool
# cool
# nah
# cool
# cool

# %%
def albumSongs(uri):
    album = uri #assign album uri to a_name

    spotify_albums[album] = {} #Creates dictionary for that specific album
    #Create keys-values of empty lists inside nested dictionary for album
    spotify_albums[album]['album'] = [] #create empty list
    spotify_albums[album]['track_number'] = []
    spotify_albums[album]['id'] = []
    spotify_albums[album]['name'] = []
    spotify_albums[album]['uri'] = []

    tracks = sp.album_tracks(album) #pull data on album tracks

    for n in range(len(tracks['items'])): #for each song track
        spotify_albums[album]['album'].append(album_names[album_count]) #append album name tracked via album_count
        spotify_albums[album]['track_number'].append(tracks['items'][n]['track_number'])
        spotify_albums[album]['id'].append(tracks['items'][n]['id'])
        spotify_albums[album]['name'].append(tracks['items'][n]['name'])
        spotify_albums[album]['uri'].append(tracks['items'][n]['uri'])

# %%
spotify_albums = {}
album_count = 0
for i in album_uris: #each album
    albumSongs(i)
    print("Album " + str(album_names[album_count]) + " songs has been added to spotify_albums dictionary")
    album_count+=1 #Updates album count once all tracks have been added
# Out:
#  Church of Rock and Roll songs has been added to spotify_albums dictionary
# Album Foxy Shazam songs has been added to spotify_albums dictionary
# Album Foxy Shazam songs has been added to spotify_albums dictionary
# Album Introducing songs has been added to spotify_albums dictionary
# Album Sojourner songs has been added to spotify_albums dictionary
# Album Grounded songs has been added to spotify_albums dictionary
# Album Deserter songs has been added to spotify_albums dictionary
# Album Drifter songs has been added to spotify_albums dictionary
# Album Tweens songs has been added to spotify_albums dictionary
# Album In Good Company songs has been added to spotify_albums dictionary
# Album High Time, Low Tide songs has been added to spotify_albums dictionary
# Album Moon songs has been added to spotify_albums dictionary
# Album Trashgrass songs has been added to spotify_albums dictionary
# Album Welcome To Metropolis songs has been added to spotify_albums dictionary
# Album 729 Tecumseh songs has been added to spotify_albums dictionary
# Album New Machines songs has been added to spotify_albums dictionary
# Album My Little Jon songs has been added to spotify_albums dictionary
# Album My Little Jon songs has been added to spotify_albums dictionary
# Album Charlie Johnson songs has been added to spotify_albums dictionary
# Album In Brazil songs has been added to spotify_albums dictionary
# Album Let Go, Jump in the River songs has been added to spotify_albums dictionary
# Album Soul Kiss songs has been added to spotify_albums dictionary
# Album Death Of A Slug songs has been added to spotify_albums dictionary
# Album As Long as the Sun Is Up songs has been added to spotify_albums dictionary
# Album Lessons & Lovers songs has been added to spotify_albums dictionary
# Album Love Detox (Special Edition) songs has been added to spotify_albums dictionary
# Album Stuff We Leave Behind songs has been added to spotify_albums dictionary
# Album Manatee songs has been added to spotify_albums dictionary
# Album Before the Dark songs has been added to spotify_albums dictionary
# Album What It Boss songs has been added to spotify_albums dictionary
# Album Fuck a Job songs has been added to spotify_albums dictionary
# Album Adventure 2 songs has been added to spotify_albums dictionary
# Album Mesmerized songs has been added to spotify_albums dictionary
# Album Dos songs has been added to spotify_albums dictionary
# Album Lemon Sky songs has been added to spotify_albums dictionary
# Album Green Grass Grows songs has been added to spotify_albums dictionary
# Album Talk to Your Babies songs has been added to spotify_albums dictionary
# Album Moment in Time songs has been added to spotify_albums dictionary
# Album Mastermind songs has been added to spotify_albums dictionary
# Album Fuck You songs has been added to spotify_albums dictionary
# Album Unkind songs has been added to spotify_albums dictionary
# Album The Electric Indigo - Live at Radio Artifact songs has been added to spotify_albums dictionary
# Album The Electric Indigo songs has been added to spotify_albums dictionary
# Album Softpack songs has been added to spotify_albums dictionary
# Album See You in the Funnies songs has been added to spotify_albums dictionary
# Album Up All Night songs has been added to spotify_albums dictionary
# Album Moonbeau songs has been added to spotify_albums dictionary
# Album Ghost Train songs has been added to spotify_albums dictionary
# Album Slow Blink songs has been added to spotify_albums dictionary
# %%
def audio_features(album):
    #Add new key-values to store audio features
    spotify_albums[album]['acousticness'] = []
    spotify_albums[album]['danceability'] = []
    spotify_albums[album]['energy'] = []
    spotify_albums[album]['instrumentalness'] = []
    spotify_albums[album]['liveness'] = []
    spotify_albums[album]['loudness'] = []
    spotify_albums[album]['speechiness'] = []
    spotify_albums[album]['tempo'] = []
    spotify_albums[album]['valence'] = []
    spotify_albums[album]['popularity'] = []
    #create a track counter
    track_count = 0
    for track in spotify_albums[album]['uri']:
        #pull audio features per track
        features = sp.audio_features(track)
        
        #Append to relevant key-value
        try:
            spotify_albums[album]['acousticness'].append(features[0]['acousticness'])
            spotify_albums[album]['danceability'].append(features[0]['danceability'])
            spotify_albums[album]['energy'].append(features[0]['energy'])
            spotify_albums[album]['instrumentalness'].append(features[0]['instrumentalness'])
            spotify_albums[album]['liveness'].append(features[0]['liveness'])
            spotify_albums[album]['loudness'].append(features[0]['loudness'])
            spotify_albums[album]['speechiness'].append(features[0]['speechiness'])
            spotify_albums[album]['tempo'].append(features[0]['tempo'])
            spotify_albums[album]['valence'].append(features[0]['valence'])
            #popularity is stored elsewhere
            pop = sp.track(track)
            spotify_albums[album]['popularity'].append(pop['popularity'])
            track_count+=1
        except:
            print('no value')
            list1 = ['50']
            spotify_albums[album]['acousticness'].append(list1)
            spotify_albums[album]['danceability'].append(list1)
            spotify_albums[album]['energy'].append(list1)
            spotify_albums[album]['instrumentalness'].append(list1)
            spotify_albums[album]['liveness'].append(list1)
            spotify_albums[album]['loudness'].append(list1)
            spotify_albums[album]['speechiness'].append(list1)
            spotify_albums[album]['tempo'].append(list1)
            spotify_albums[album]['valence'].append(list1)
            #popularity is stored elsewhere
            pop = sp.track(track)
            spotify_albums[album]['popularity'].append(list1)
            track_count+=1

# %%
sp = spotipy.Spotify(auth=token)

# %%
# spotify_albums

# %%
import time
import numpy as np
import random
# sleep_min = 0.1
# sleep_max = 0.4
start_time = time.time()
request_count = 0
for i in spotify_albums:
    rand = random.randint(1, 100)
    if rand>95:
        sp = spotipy.Spotify(auth=token)
        print("refresh~~~")
    else:
        print("good!")
    audio_features(i)
    request_count+=1
    if request_count % 5 == 0:
        print(str(request_count) + " playlists completed")
        print('Loop #: {}'.format(request_count))
        print('Elapsed Time: {} seconds'.format(time.time() - start_time))
# Out:
# good!
# good!
# good!
# good!
# good!
# 5 playlists completed
# Loop #: 5
# Elapsed Time: 14.82897663116455 seconds
# good!
# good!
# good!
# refresh~~~
# good!
# 10 playlists completed
# Loop #: 10
# Elapsed Time: 26.747432231903076 seconds
# good!
# good!
# good!
# good!
# good!
# 15 playlists completed
# Loop #: 15
# Elapsed Time: 39.48490905761719 seconds
# good!
# good!
# good!
# good!
# good!
# 20 playlists completed
# Loop #: 20
# Elapsed Time: 59.49910807609558 seconds
# good!
# good!
# good!
# good!
# good!
# 25 playlists completed
# Loop #: 25
# Elapsed Time: 76.36715006828308 seconds
# good!
# good!
# good!
# good!
# good!
# 30 playlists completed
# Loop #: 30
# Elapsed Time: 86.83757448196411 seconds
# good!
# good!
# good!
# good!
# good!
# 35 playlists completed
# Loop #: 35
# Elapsed Time: 97.23570227622986 seconds
# good!
# good!
# good!
# good!
# good!
# 40 playlists completed
# Loop #: 40
# Elapsed Time: 108.476233959198 seconds
# good!
# good!
# good!
# good!
# good!
# 45 playlists completed
# Loop #: 45
# Elapsed Time: 119.07011556625366 seconds
# good!
# good!
# refresh~~~
# good!
# good!
# 50 playlists completed
# Loop #: 50
# Elapsed Time: 130.63787198066711 seconds
# good!
# good!
# good!
# good!
# good!
# 55 playlists completed
# Loop #: 55
# Elapsed Time: 140.61776542663574 seconds
# good!
# good!
# good!
# good!
# good!
# 60 playlists completed
# Loop #: 60
# Elapsed Time: 155.04980897903442 seconds
# good!
# good!
# good!
# good!
# good!
# 65 playlists completed
# Loop #: 65
# Elapsed Time: 165.74980187416077 seconds
# good!
# good!
# good!
# good!
# good!
# 70 playlists completed
# Loop #: 70
# Elapsed Time: 177.74684929847717 seconds
# good!
# good!
# good!
# good!
# good!
# 75 playlists completed
# Loop #: 75
# Elapsed Time: 188.03899765014648 seconds
# good!
# good!
# good!
# good!
# good!
# 80 playlists completed
# Loop #: 80
# Elapsed Time: 200.34110307693481 seconds
# refresh~~~
# good!
# good!
# good!
# good!
#
# Loop #: 590
# Elapsed Time: 1339.3133754730225 seconds
# good!
# good!
# good!
# good!
# good!
# 595 playlists completed
# Loop #: 595
# Elapsed Time: 1354.5588853359222 seconds
# good!
# refresh~~~
# good!
# good!
# good!
# 600 playlists completed
# Loop #: 600
# Elapsed Time: 1365.1914191246033 seconds
# good!
# good!
# good!
# good!
# good!
# 605 playlists completed
# Loop #: 605
# Elapsed Time: 1376.357322692871 seconds
# good!
# good!
# good!
# refresh~~~
# good!
# 610 playlists completed
# Loop #: 610
# Elapsed Time: 1385.7321662902832 seconds
# good!
# good!
# good!
# good!
# good!
# 615 playlists completed
# Loop #: 615
# Elapsed Time: 1396.455932855606 seconds
# good!
# good!

# %%
dic_df = {}
dic_df['album'] = []
dic_df['track_number'] = []
dic_df['id'] = []
dic_df['name'] = []
dic_df['uri'] = []
dic_df['acousticness'] = []
dic_df['danceability'] = []
dic_df['energy'] = []
dic_df['instrumentalness'] = []
dic_df['liveness'] = []
dic_df['loudness'] = []
dic_df['speechiness'] = []
dic_df['tempo'] = []
dic_df['valence'] = []
dic_df['popularity'] = []
for album in spotify_albums: 
    for feature in spotify_albums[album]:
        dic_df[feature].extend(spotify_albums[album][feature])
        
len(dic_df['album'])
# Out:
# 7010

# %%
print(
len(dic_df['album']),
len(dic_df['track_number']),
len(dic_df['id']),
len(dic_df['name']),
len(dic_df['uri']),
len(dic_df['acousticness']),
len(dic_df['danceability']),
len(dic_df['energy']),
len(dic_df['instrumentalness']),
len(dic_df['liveness']),
len(dic_df['loudness']),
len(dic_df['speechiness']),
len(dic_df['tempo']),
len(dic_df['valence']),
len(dic_df['popularity'])
)
# Out:
# 7010 7010 7010 7010 7010 7010 7010 7010 7010 7010 7010 7010 7010 7010 7010

# %%
types1 = [type(k) for k in dic_df.values()]
types1
# Out:
# [list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list]

# %%
print(
len(dic_df['album']),
len(dic_df['track_number']),
len(dic_df['id']),
len(dic_df['name']),
len(dic_df['uri']),
len(dic_df['acousticness']),
len(dic_df['danceability']),
len(dic_df['energy']),
len(dic_df['instrumentalness'])
)
# Out:
# 7010 7010 7010 7010 7010 7010 7010 7010 7010

# %%
dic_df = {}
dic_df['album'] = []
dic_df['track_number'] = []
dic_df['id'] = []
dic_df['name'] = []
dic_df['uri'] = []
dic_df['acousticness'] = []
dic_df['danceability'] = []
dic_df['energy'] = []
dic_df['instrumentalness'] = []
dic_df['liveness'] = []
dic_df['loudness'] = []
dic_df['speechiness'] = []
dic_df['tempo'] = []
dic_df['valence'] = []
dic_df['popularity'] = []
for album in spotify_albums: 
    for feature in spotify_albums[album]:
        dic_df[feature].extend(spotify_albums[album][feature])
        
len(dic_df['album'])

import pandas as pd
df = pd.DataFrame.from_dict(dic_df, orient='index') # editing here to fix not same length issue
df
# Out:
#                                                   0     \
# album                                 Strange Creature
# track_number                                         1
# id                              6uf9o4z7idDToNapgOjhWl
# name                                   Not Coming Home
# uri               spotify:track:6uf9o4z7idDToNapgOjhWl
# acousticness                                  0.000819
# danceability                                     0.462
# energy                                           0.971
# instrumentalness                                0.0949
# liveness                                         0.103
# loudness                                         -4.36
# speechiness                                     0.0843
# tempo                                          148.016
# valence                                          0.625
# popularity                                           7
#
#                                                   1     \
# album                                 Strange Creature
# track_number                                         2
# id                              6aIJJpgXw6lIpdNyrYNZ4z
# name                                      Expectations
# uri               spotify:track:6aIJJpgXw6lIpdNyrYNZ4z
# acousticness                                   0.00497
# danceability                                     0.596
# energy                                           0.878
# instrumentalness                               0.00173
# liveness                                        0.0469
# loudness                                        -5.577
# speechiness                                     0.0344
# tempo                                          132.907
# valence                                          0.773
# popularity                                           5
#
#                                                       2     \
# album                                     Strange Creature
# track_number                                             3
# id                                  780UXpdK9AAYgLuFxTpEgX
# name              First Time Let Down (Not the First Time)
# uri                   spotify:track:780UXpdK9AAYgLuFxTpEgX
# acousticness                                        0.0107
# danceability                                          0.31
# energy                                               0.802
# instrumentalness                                     0.561
# liveness                                             0.162
# loudness                                            -5.544
# speechiness                                         0.0381
# tempo                                              169.001
# valence                                              0.714
# popularity                                               6
#
#                                                   3     \
# album                                 Strange Creature
# track_number                                         4
# id                              6cuwLWRsxS4x3Qpm8gJCts
# name                                      Never Listen
# uri               spotify:track:6cuwLWRsxS4x3Qpm8gJCts
# acousticness                                    0.0851
# danceability                                     0.505
# energy                                            0.73
# instrumentalness                                0.0479
# liveness                                         0.186
# loudness                                        -7.246
# speechiness                                      0.136
# tempo                                          170.162
# valence                                          0.929
# popularity                                           3
#
#                                                   4     \
# album                                 Strange Creature
# track_number                                         5
# id                              38F2tGTFqUYkkwO1tXZDXF
# name                                          Wormhole
# uri               spotify:track:38F2tGTFqUYkkwO1tXZDXF
# acousticness                                      0.12
# danceability                                     0.704
# energy                                           0.728
# instrumentalness                                 0.897
# liveness                                        0.0793
# loudness                                        -9.873
# speechiness                                     0.0689
# tempo                                          114.996
# valence                                          0.322
# popularity                                           3
#
#                                                   5     \
# album                                 Strange Creature
# track_number                                         6
# id                              5Jtg1eR11Fo0vEuaq3PFWE
# name                                     Power over Me
# uri               spotify:track:5Jtg1eR11Fo0vEuaq3PFWE
# acousticness                                    0.0276
# danceability                                     0.695
# energy                                           0.695
# instrumentalness                                 0.033
# liveness                                        0.0687
# loudness                                        -6.528
# speechiness                                      0.032
# tempo                                          152.357
# valence                                          0.901
# popularity                                           4
#
#                                                   6     \
# album                                 Strange Creature
# track_number                                         7
# id                              66c8ii4FjJLlKzgR2Yo4aL
# name                                       Apart of Me
# uri               spotify:track:66c8ii4FjJLlKzgR2Yo4aL
# acousticness                                    0.0156
# danceability                                     0.438
# energy                                            0.66
# instrumentalness                               0.00348
# liveness                                        0.0569
# loudness                                        -4.884
# speechiness                                     0.0395
# tempo                                          124.603
# valence                                          0.778
# popularity                                           4
#
#                                                   7     \
# album                                 Strange Creature
# track_number                                         8
# id                              7rHLJis4SNLa0IhSakbgO5
# name                     Everybody Wants to Be Someone
# uri               spotify:track:7rHLJis4SNLa0IhSakbgO5
# acousticness                                    0.0671
# danceability                                     0.549
# energy                                           0.937
# instrumentalness                                0.0149
# liveness                                        0.0741
# loudness                                         -6.22
# speechiness                                     0.0349
# tempo                                          158.985
# valence                                          0.822
# popularity                                           4
#
#                                                   8     \
# album                                 Strange Creature
# track_number                                         9
# id                              5hK92X6nc7senJN1yN69o8
# name                                               6/8
# uri               spotify:track:5hK92X6nc7senJN1yN69o8
# acousticness                                    0.0591
# danceability                                     0.458
# energy                                           0.612
# instrumentalness                                  0.84
# liveness                                        0.0989
# loudness                                        -8.054
# speechiness                                     0.0434
# tempo                                           90.054
# valence                                          0.803
# popularity                                           7
#
#                                                   9     ...  \
# album                                 Strange Creature  ...
# track_number                                        10  ...
# id                              1EScaYJt33Knet6kmgT2tZ  ...
# name                                         Coachella  ...
# uri               spotify:track:1EScaYJt33Knet6kmgT2tZ  ...
# acousticness                                     0.894  ...
# danceability                                     0.417  ...
# energy                                            0.29  ...
# instrumentalness                                 0.955  ...
# liveness                                        0.0675  ...
# loudness                                       -22.644  ...
# speechiness                                     0.0352  ...
# tempo                                           91.697  ...
# valence                                         0.0853  ...
# popularity                                           2  ...
#
#                                                   7000  \
# album                        Bolero Ranchero Romantico
# track_number                                         3
# id                              4POZXw0AbCVklBTI72PY9t
# name                                        Cielo Rojo
# uri               spotify:track:4POZXw0AbCVklBTI72PY9t
# acousticness                                     0.657
# danceability                                     0.387
# energy                                           0.563
# instrumentalness                               6.6e-06
# liveness                                          0.96
# loudness                                        -9.025
# speechiness                                     0.0653
# tempo                                          127.533
# valence                                          0.894
# popularity                                           0
#
#                                                   7001  \
# album                        Bolero Ranchero Romantico
# track_number                                         4
# id                              4GEVKTzWS5ShorpUvVXxK0
# name                                      Cuatro Meses
# uri               spotify:track:4GEVKTzWS5ShorpUvVXxK0
# acousticness                                     0.681
# danceability                                     0.597
# energy                                           0.508
# instrumentalness                                     0
# liveness                                         0.154
# loudness                                          -7.4
# speechiness                                     0.0806
# tempo                                          190.131
# valence                                          0.908
# popularity                                           0
#
#                                                   7002  \
# album                        Bolero Ranchero Romantico
# track_number                                         5
# id                              1DxtuHgqqjGS1TOae6jxL7
# name                                    El Tiempo Pasa
# uri               spotify:track:1DxtuHgqqjGS1TOae6jxL7
# acousticness                                     0.226
# danceability                                     0.564
# energy                                           0.409
# instrumentalness                              2.69e-05
# liveness                                        0.0763
# loudness                                        -7.372
# speechiness                                      0.033
# tempo                                           82.665
# valence                                          0.745
# popularity                                           0
#
#                                                   7003  \
# album                        Bolero Ranchero Romantico
# track_number                                         6
# id                              0EXrv5u38nW3RGgvISnugZ
# name                           Entre Cantina Y Cantina
# uri               spotify:track:0EXrv5u38nW3RGgvISnugZ
# acousticness                                     0.636
# danceability                                     0.542
# energy                                           0.273
# instrumentalness                                     0
# liveness                                        0.0808
# loudness                                        -8.046
# speechiness                                     0.0306
# tempo                                           91.504
# valence                                          0.495
# popularity                                           0
#
#                                                   7004  \
# album                        Bolero Ranchero Romantico
# track_number                                         7
# id                              2rrszxNRvMuFCL7LLbJQ3O
# name                                         La Vikina
# uri               spotify:track:2rrszxNRvMuFCL7LLbJQ3O
# acousticness                                     0.734
# danceability                                     0.536
# energy                                           0.561
# instrumentalness                                  0.09
# liveness                                         0.415
# loudness                                        -1.231
# speechiness                                     0.0328
# tempo                                          100.259
# valence                                          0.443
# popularity                                           0
#
#                                                   7005  \
# album                        Bolero Ranchero Romantico
# track_number                                         8
# id                              2bFrwGFklnos44ucqUFgEP
# name                                   No Me Queda Mas
# uri               spotify:track:2bFrwGFklnos44ucqUFgEP
# acousticness                                     0.216
# danceability                                     0.569
# energy                                           0.825
# instrumentalness                              2.31e-06
# liveness                                        0.0759
# loudness                                        -4.078
# speechiness                                     0.0396
# tempo                                          148.164
# valence                                          0.921
# popularity                                           0
#
#                                                   7006  \
# album                        Bolero Ranchero Romantico
# track_number                                         9
# id                              2xtfRBiM0PpU4DrmeR7c6H
# name                                      Paloma Negra
# uri               spotify:track:2xtfRBiM0PpU4DrmeR7c6H
# acousticness                                     0.335
# danceability                                     0.729
# energy                                           0.342
# instrumentalness                              5.04e-06
# liveness                                         0.113
# loudness                                        -7.046
# speechiness                                     0.0348
# tempo                                          119.697
# valence                                          0.799
# popularity                                           0
#
#                                                   7007  \
# album                        Bolero Ranchero Romantico
# track_number                                        10
# id                              6Wnjslfi7C71aPMxRcXfYY
# name                                 Serenata Huasteca
# uri               spotify:track:6Wnjslfi7C71aPMxRcXfYY
# acousticness                                       0.5
# danceability                                     0.862
# energy                                           0.507
# instrumentalness                              0.000935
# liveness                                        0.0797
# loudness                                        -9.071
# speechiness                                     0.0391
# tempo                                          101.005
# valence                                          0.844
# popularity                                           0
#
#                                                   7008  \
# album                        Bolero Ranchero Romantico
# track_number                                        11
# id                              40Nl04ijHGrkq6aivshvQX
# name                                Todavia Me Acuerda
# uri               spotify:track:40Nl04ijHGrkq6aivshvQX
# acousticness                                     0.254
# danceability                                     0.749
# energy                                            0.63
# instrumentalness                                     0
# liveness                                        0.0505
# loudness                                       -10.822
# speechiness                                     0.0687
# tempo                                          178.175
# valence                                          0.826
# popularity                                           0
#
#                                                   7009
# album                        Bolero Ranchero Romantico
# track_number                                        12
# id                              0aaNzpSFHM12j8BflDCbwI
# name                                         Yo No Fui
# uri               spotify:track:0aaNzpSFHM12j8BflDCbwI
# acousticness                                     0.357
# danceability                                     0.759
# energy                                           0.474
# instrumentalness                              1.08e-05
# liveness                                         0.118
# loudness                                       -12.649
# speechiness                                     0.0294
# tempo                                           92.529
# valence                                          0.919
# popularity                                           0
#
# [15 rows x 7010 columns]

# %%
df = df.transpose()
df
# Out:
#                           album track_number                      id  \
# 0              Strange Creature            1  6uf9o4z7idDToNapgOjhWl
# 1              Strange Creature            2  6aIJJpgXw6lIpdNyrYNZ4z
# 2              Strange Creature            3  780UXpdK9AAYgLuFxTpEgX
# 3              Strange Creature            4  6cuwLWRsxS4x3Qpm8gJCts
# 4              Strange Creature            5  38F2tGTFqUYkkwO1tXZDXF
# ...                         ...          ...                     ...
# 7005  Bolero Ranchero Romantico            8  2bFrwGFklnos44ucqUFgEP
# 7006  Bolero Ranchero Romantico            9  2xtfRBiM0PpU4DrmeR7c6H
# 7007  Bolero Ranchero Romantico           10  6Wnjslfi7C71aPMxRcXfYY
# 7008  Bolero Ranchero Romantico           11  40Nl04ijHGrkq6aivshvQX
# 7009  Bolero Ranchero Romantico           12  0aaNzpSFHM12j8BflDCbwI
#
#                                           name  \
# 0                              Not Coming Home
# 1                                 Expectations
# 2     First Time Let Down (Not the First Time)
# 3                                 Never Listen
# 4                                     Wormhole
# ...                                        ...
# 7005                           No Me Queda Mas
# 7006                              Paloma Negra
# 7007                         Serenata Huasteca
# 7008                        Todavia Me Acuerda
# 7009                                 Yo No Fui
#
#                                        uri acousticness danceability energy  \
# 0     spotify:track:6uf9o4z7idDToNapgOjhWl     0.000819        0.462  0.971
# 1     spotify:track:6aIJJpgXw6lIpdNyrYNZ4z      0.00497        0.596  0.878
# 2     spotify:track:780UXpdK9AAYgLuFxTpEgX       0.0107         0.31  0.802
# 3     spotify:track:6cuwLWRsxS4x3Qpm8gJCts       0.0851        0.505   0.73
# 4     spotify:track:38F2tGTFqUYkkwO1tXZDXF         0.12        0.704  0.728
# ...                                    ...          ...          ...    ...
# 7005  spotify:track:2bFrwGFklnos44ucqUFgEP        0.216        0.569  0.825
# 7006  spotify:track:2xtfRBiM0PpU4DrmeR7c6H        0.335        0.729  0.342
# 7007  spotify:track:6Wnjslfi7C71aPMxRcXfYY          0.5        0.862  0.507
# 7008  spotify:track:40Nl04ijHGrkq6aivshvQX        0.254        0.749   0.63
# 7009  spotify:track:0aaNzpSFHM12j8BflDCbwI        0.357        0.759  0.474
#
#      instrumentalness liveness loudness speechiness    tempo valence  \
# 0              0.0949    0.103    -4.36      0.0843  148.016   0.625
# 1             0.00173   0.0469   -5.577      0.0344  132.907   0.773
# 2               0.561    0.162   -5.544      0.0381  169.001   0.714
# 3              0.0479    0.186   -7.246       0.136  170.162   0.929
# 4               0.897   0.0793   -9.873      0.0689  114.996   0.322
# ...               ...      ...      ...         ...      ...     ...
# 7005         2.31e-06   0.0759   -4.078      0.0396  148.164   0.921
# 7006         5.04e-06    0.113   -7.046      0.0348  119.697   0.799
# 7007         0.000935   0.0797   -9.071      0.0391  101.005   0.844
# 7008                0   0.0505  -10.822      0.0687  178.175   0.826
# 7009         1.08e-05    0.118  -12.649      0.0294   92.529   0.919
#
#      popularity
# 0             7
# 1             5
# 2             6
# 3             3
# 4             3
# ...         ...
# 7005          0
# 7006          0
# 7007          0
# 7008          0
# 7009          0
#
# [7010 rows x 15 columns]

# %%
df
# Out:
#                           album track_number                      id  \
# 0              Strange Creature            1  6uf9o4z7idDToNapgOjhWl
# 1              Strange Creature            2  6aIJJpgXw6lIpdNyrYNZ4z
# 2              Strange Creature            3  780UXpdK9AAYgLuFxTpEgX
# 3              Strange Creature            4  6cuwLWRsxS4x3Qpm8gJCts
# 4              Strange Creature            5  38F2tGTFqUYkkwO1tXZDXF
# ...                         ...          ...                     ...
# 7005  Bolero Ranchero Romantico            8  2bFrwGFklnos44ucqUFgEP
# 7006  Bolero Ranchero Romantico            9  2xtfRBiM0PpU4DrmeR7c6H
# 7007  Bolero Ranchero Romantico           10  6Wnjslfi7C71aPMxRcXfYY
# 7008  Bolero Ranchero Romantico           11  40Nl04ijHGrkq6aivshvQX
# 7009  Bolero Ranchero Romantico           12  0aaNzpSFHM12j8BflDCbwI
#
#                                           name  \
# 0                              Not Coming Home
# 1                                 Expectations
# 2     First Time Let Down (Not the First Time)
# 3                                 Never Listen
# 4                                     Wormhole
# ...                                        ...
# 7005                           No Me Queda Mas
# 7006                              Paloma Negra
# 7007                         Serenata Huasteca
# 7008                        Todavia Me Acuerda
# 7009                                 Yo No Fui
#
#                                        uri acousticness danceability energy  \
# 0     spotify:track:6uf9o4z7idDToNapgOjhWl     0.000819        0.462  0.971
# 1     spotify:track:6aIJJpgXw6lIpdNyrYNZ4z      0.00497        0.596  0.878
# 2     spotify:track:780UXpdK9AAYgLuFxTpEgX       0.0107         0.31  0.802
# 3     spotify:track:6cuwLWRsxS4x3Qpm8gJCts       0.0851        0.505   0.73
# 4     spotify:track:38F2tGTFqUYkkwO1tXZDXF         0.12        0.704  0.728
# ...                                    ...          ...          ...    ...
# 7005  spotify:track:2bFrwGFklnos44ucqUFgEP        0.216        0.569  0.825
# 7006  spotify:track:2xtfRBiM0PpU4DrmeR7c6H        0.335        0.729  0.342
# 7007  spotify:track:6Wnjslfi7C71aPMxRcXfYY          0.5        0.862  0.507
# 7008  spotify:track:40Nl04ijHGrkq6aivshvQX        0.254        0.749   0.63
# 7009  spotify:track:0aaNzpSFHM12j8BflDCbwI        0.357        0.759  0.474
#
#      instrumentalness liveness loudness speechiness    tempo valence  \
# 0              0.0949    0.103    -4.36      0.0843  148.016   0.625
# 1             0.00173   0.0469   -5.577      0.0344  132.907   0.773
# 2               0.561    0.162   -5.544      0.0381  169.001   0.714
# 3              0.0479    0.186   -7.246       0.136  170.162   0.929
# 4               0.897   0.0793   -9.873      0.0689  114.996   0.322
# ...               ...      ...      ...         ...      ...     ...
# 7005         2.31e-06   0.0759   -4.078      0.0396  148.164   0.921
# 7006         5.04e-06    0.113   -7.046      0.0348  119.697   0.799
# 7007         0.000935   0.0797   -9.071      0.0391  101.005   0.844
# 7008                0   0.0505  -10.822      0.0687  178.175   0.826
# 7009         1.08e-05    0.118  -12.649      0.0294   92.529   0.919
#
#      popularity
# 0             7
# 1             5
# 2             6
# 3             3
# 4             3
# ...         ...
# 7005          0
# 7006          0
# 7007          0
# 7008          0
# 7009          0
#
# [7010 rows x 15 columns]

# %%
# df_top5_per = 
df.sort_values('popularity', ascending=False)
# Out:
#                           album track_number                      id  \
# 179                   Ego Death            7  3PFaFVWq5wucLu6s4baj9D
# 184                   Ego Death           12  300DUx4tdtCdGEUXR032jA
# 180                   Ego Death            8  3NWTRZ0A8xKlBP1qgNftql
# 146                   Hive Mind           13  5tqZJUHEuqdN12RZVq2l9p
# 136                   Hive Mind            3  2hPNuVVSV1tqiD2uPlfehz
# ...                         ...          ...                     ...
# 2874       Stargaze Rock n Roll            2  3JtoEMLiHf9P1QtGN5Cetr
# 2872         Desperate Measures           12  4pvghEAQYJ39aJVMWfLlNh
# 2871         Desperate Measures           11  2YmArKIT5MZArlq3w3AAot
# 2870         Desperate Measures           10  4VyDwsfyAfU6GTw5Wi4O67
# 7009  Bolero Ranchero Romantico           12  0aaNzpSFHM12j8BflDCbwI
#
#                                                    name  \
# 179                             Girl (feat. KAYTRANADA)
# 184   Palace/Curse (feat. Steve Lacy, feat. Tyler, T...
# 180                                      Special Affair
# 146                                             Hold On
# 136                                           Come Over
# ...                                                 ...
# 2874                                            Sodapop
# 2872                                 Desperate Measures
# 2871                                       Definite Aim
# 2870                                     Jfk Killed Fdr
# 7009                                          Yo No Fui
#
#                                        uri acousticness danceability energy  \
# 179   spotify:track:3PFaFVWq5wucLu6s4baj9D        0.536        0.568   0.42
# 184   spotify:track:300DUx4tdtCdGEUXR032jA       0.0351        0.447  0.625
# 180   spotify:track:3NWTRZ0A8xKlBP1qgNftql        0.183        0.795  0.409
# 146   spotify:track:5tqZJUHEuqdN12RZVq2l9p        0.849          0.7  0.414
# 136   spotify:track:2hPNuVVSV1tqiD2uPlfehz       0.0968        0.529  0.598
# ...                                    ...          ...          ...    ...
# 2874  spotify:track:3JtoEMLiHf9P1QtGN5Cetr      0.00356        0.319  0.635
# 2872  spotify:track:4pvghEAQYJ39aJVMWfLlNh        0.128        0.497  0.955
# 2871  spotify:track:2YmArKIT5MZArlq3w3AAot         0.26        0.518   0.89
# 2870  spotify:track:4VyDwsfyAfU6GTw5Wi4O67       0.0905        0.569  0.607
# 7009  spotify:track:0aaNzpSFHM12j8BflDCbwI        0.357        0.759  0.474
#
#      instrumentalness liveness loudness speechiness    tempo valence  \
# 179             0.124    0.101  -11.169       0.276    79.89   0.453
# 184          0.000727    0.243   -8.212       0.323   67.104   0.261
# 180           0.00108    0.112  -10.134      0.0859  120.095   0.518
# 146            0.0606    0.107  -10.864      0.0373   60.479   0.444
# 136             0.171    0.189   -7.951       0.187    92.01   0.691
# ...               ...      ...      ...         ...      ...     ...
# 2874            0.659    0.309   -3.766      0.0393  126.013   0.456
# 2872                0    0.448   -2.235       0.168   84.922   0.606
# 2871                0   0.0862   -3.336       0.256   81.095   0.652
# 2870                0    0.322   -3.544       0.418   69.954   0.858
# 7009         1.08e-05    0.118  -12.649      0.0294   92.529   0.919
#
#      popularity
# 179          68
# 184          67
# 180          65
# 146          63
# 136          60
# ...         ...
# 2874          0
# 2872          0
# 2871          0
# 2870          0
# 7009          0
#
# [7010 rows x 15 columns]

# %%
print(len(df))
# final_df = df.sort_values('popularity', ascending=False).drop_duplicates('name').sort_index()
final_df = df.drop_duplicates('name').sort_index()
print(len(final_df))
# Out:
# 7010
# 6379

# %%
final_df.to_csv("final_df_master_cincy.csv", sep = ',')

# %%
final_df.head(3)
# Out:
#               album track_number                      id  \
# 0  Strange Creature            1  6uf9o4z7idDToNapgOjhWl
# 1  Strange Creature            2  6aIJJpgXw6lIpdNyrYNZ4z
# 2  Strange Creature            3  780UXpdK9AAYgLuFxTpEgX
#
#                                        name  \
# 0                           Not Coming Home
# 1                              Expectations
# 2  First Time Let Down (Not the First Time)
#
#                                     uri acousticness danceability energy  \
# 0  spotify:track:6uf9o4z7idDToNapgOjhWl     0.000819        0.462  0.971
# 1  spotify:track:6aIJJpgXw6lIpdNyrYNZ4z      0.00497        0.596  0.878
# 2  spotify:track:780UXpdK9AAYgLuFxTpEgX       0.0107         0.31  0.802
#
#   instrumentalness liveness loudness speechiness    tempo valence popularity
# 0           0.0949    0.103    -4.36      0.0843  148.016   0.625          7
# 1          0.00173   0.0469   -5.577      0.0344  132.907   0.773          5
# 2            0.561    0.162   -5.544      0.0381  169.001   0.714          6

# %%
import numpy as np
final_df['meets_popularity_cutoff'] = np.where((final_df['popularity']>0) , 'yes', 'no')
final_df
# Out:
#                           album track_number                      id  \
# 0              Strange Creature            1  6uf9o4z7idDToNapgOjhWl
# 1              Strange Creature            2  6aIJJpgXw6lIpdNyrYNZ4z
# 2              Strange Creature            3  780UXpdK9AAYgLuFxTpEgX
# 3              Strange Creature            4  6cuwLWRsxS4x3Qpm8gJCts
# 4              Strange Creature            5  38F2tGTFqUYkkwO1tXZDXF
# ...                         ...          ...                     ...
# 7005  Bolero Ranchero Romantico            8  2bFrwGFklnos44ucqUFgEP
# 7006  Bolero Ranchero Romantico            9  2xtfRBiM0PpU4DrmeR7c6H
# 7007  Bolero Ranchero Romantico           10  6Wnjslfi7C71aPMxRcXfYY
# 7008  Bolero Ranchero Romantico           11  40Nl04ijHGrkq6aivshvQX
# 7009  Bolero Ranchero Romantico           12  0aaNzpSFHM12j8BflDCbwI
#
#                                           name  \
# 0                              Not Coming Home
# 1                                 Expectations
# 2     First Time Let Down (Not the First Time)
# 3                                 Never Listen
# 4                                     Wormhole
# ...                                        ...
# 7005                           No Me Queda Mas
# 7006                              Paloma Negra
# 7007                         Serenata Huasteca
# 7008                        Todavia Me Acuerda
# 7009                                 Yo No Fui
#
#                                        uri acousticness danceability energy  \
# 0     spotify:track:6uf9o4z7idDToNapgOjhWl     0.000819        0.462  0.971
# 1     spotify:track:6aIJJpgXw6lIpdNyrYNZ4z      0.00497        0.596  0.878
# 2     spotify:track:780UXpdK9AAYgLuFxTpEgX       0.0107         0.31  0.802
# 3     spotify:track:6cuwLWRsxS4x3Qpm8gJCts       0.0851        0.505   0.73
# 4     spotify:track:38F2tGTFqUYkkwO1tXZDXF         0.12        0.704  0.728
# ...                                    ...          ...          ...    ...
# 7005  spotify:track:2bFrwGFklnos44ucqUFgEP        0.216        0.569  0.825
# 7006  spotify:track:2xtfRBiM0PpU4DrmeR7c6H        0.335        0.729  0.342
# 7007  spotify:track:6Wnjslfi7C71aPMxRcXfYY          0.5        0.862  0.507
# 7008  spotify:track:40Nl04ijHGrkq6aivshvQX        0.254        0.749   0.63
# 7009  spotify:track:0aaNzpSFHM12j8BflDCbwI        0.357        0.759  0.474
#
#      instrumentalness liveness loudness speechiness    tempo valence  \
# 0              0.0949    0.103    -4.36      0.0843  148.016   0.625
# 1             0.00173   0.0469   -5.577      0.0344  132.907   0.773
# 2               0.561    0.162   -5.544      0.0381  169.001   0.714
# 3              0.0479    0.186   -7.246       0.136  170.162   0.929
# 4               0.897   0.0793   -9.873      0.0689  114.996   0.322
# ...               ...      ...      ...         ...      ...     ...
# 7005         2.31e-06   0.0759   -4.078      0.0396  148.164   0.921
# 7006         5.04e-06    0.113   -7.046      0.0348  119.697   0.799
# 7007         0.000935   0.0797   -9.071      0.0391  101.005   0.844
# 7008                0   0.0505  -10.822      0.0687  178.175   0.826
# 7009         1.08e-05    0.118  -12.649      0.0294   92.529   0.919
#
#      popularity meets_popularity_cutoff
# 0             7                     yes
# 1             5                     yes
# 2             6                     yes
# 3             3                     yes
# 4             3                     yes
# ...         ...                     ...
# 7005          0                      no
# 7006          0                      no
# 7007          0                      no
# 7008          0                      no
# 7009          0                      no
#
# [6379 rows x 16 columns]

# %%
len(final_df)
# Out:
# 6379

# %%
len(pop_only)
# Out:
# 2750

# %%
pop_only = final_df.loc[final_df['meets_popularity_cutoff'] == 'yes']
pop_only = pop_only[['id']]
# pop_only = pop_only.reset_index()
# pop_only = pop_only.reset_index().drop_duplicates(keep='first', inplace=True)
pop_only
# Out:
#                           id
# 0     6uf9o4z7idDToNapgOjhWl
# 1     6aIJJpgXw6lIpdNyrYNZ4z
# 2     780UXpdK9AAYgLuFxTpEgX
# 3     6cuwLWRsxS4x3Qpm8gJCts
# 4     38F2tGTFqUYkkwO1tXZDXF
# ...                      ...
# 6973  0NiuwPuH9jTzDtoIUyCmio
# 6974  0OWc280lmJggEfqqRE28zA
# 6975  3X8KX4CPQErCZL9o9g1Dgy
# 6976  5xQ5CViABCBGgFhtjiQrn9
# 6978  0Fny42PBHg0EZcFYfdZ6Tp
#
# [2624 rows x 1 columns]

# %%
input_bands = list(set(pop_only)) # removes dups
playlist_id = '3xl8zdeD6BhjQ0u1TUWiTa'

# %%
# token = auth.get_access_token()
token = util.prompt_for_user_token(username=USERNAME, scope = 'playlist-modify user-read-private' , client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET, redirect_uri=SPOTIPY_REDIRECT_URI)
spotify = spotipy.Spotify(auth=token)
sp = spotipy.Spotify(auth=token)

# %%
pop_only
# Out:
#                           id
# 0     6uf9o4z7idDToNapgOjhWl
# 1     6aIJJpgXw6lIpdNyrYNZ4z
# 2     780UXpdK9AAYgLuFxTpEgX
# 3     6cuwLWRsxS4x3Qpm8gJCts
# 4     38F2tGTFqUYkkwO1tXZDXF
# ...                      ...
# 6973  0NiuwPuH9jTzDtoIUyCmio
# 6974  0OWc280lmJggEfqqRE28zA
# 6975  3X8KX4CPQErCZL9o9g1Dgy
# 6976  5xQ5CViABCBGgFhtjiQrn9
# 6978  0Fny42PBHg0EZcFYfdZ6Tp
#
# [2624 rows x 1 columns]

# %%
pop_only_list = pop_only['id'].drop_duplicates().to_list()
# pop_only_list.pop(0) 
pop_only_list
len('3D4MnRNEfWXxjIOSp2Oo2L')
# Out:
# 22

# %%
pop_only_list = [item for item in pop_only_list if len(item[2]) != 22]
pop_only_list[0:5]
# Out:
# ['6uf9o4z7idDToNapgOjhWl',
#  '6aIJJpgXw6lIpdNyrYNZ4z',
#  '780UXpdK9AAYgLuFxTpEgX',
#  '6cuwLWRsxS4x3Qpm8gJCts',
#  '38F2tGTFqUYkkwO1tXZDXF']

# %%
len(pop_only_list)
# Out:
# 2624

# %%
pop_only_list_short = pop_only_list[:100]
len(pop_only_list_short)
# Out:
# 100

# %%
# CINCY TOTAL 2.0
playlist_id = '0THAuat95RJGcS5TssbJSy'

pop_only_list_1 = pop_only_list[:100]
pop_only_list_2 = pop_only_list[101:200]
pop_only_list_3 = pop_only_list[201:300]
pop_only_list_4 = pop_only_list[301:400]
pop_only_list_5 = pop_only_list[401:500]
pop_only_list_6 = pop_only_list[501:600]
pop_only_list_7 = pop_only_list[601:700]
pop_only_list_8 = pop_only_list[701:800]
pop_only_list_9 = pop_only_list[801:900]
pop_only_list_10 = pop_only_list[901:1000]
pop_only_list_11 = pop_only_list[1000:1100]
pop_only_list_12 = pop_only_list[1101:1200]
pop_only_list_13 = pop_only_list[1201:1300]
pop_only_list_14 = pop_only_list[1301:1400]
pop_only_list_15 = pop_only_list[1401:1500]
pop_only_list_16 = pop_only_list[1501:1600]
pop_only_list_17 = pop_only_list[1601:1700]
pop_only_list_18 = pop_only_list[1701:1800]
pop_only_list_19 = pop_only_list[1801:1900]
pop_only_list_20 = pop_only_list[1901:2000]
pop_only_list_21 = pop_only_list[2001:2100]
pop_only_list_22 = pop_only_list[2101:2200]
pop_only_list_23 = pop_only_list[2201:2300]
pop_only_list_24 = pop_only_list[2301:2400]
pop_only_list_25 = pop_only_list[2401:2500]
pop_only_list_26 = pop_only_list[2501:2600]
pop_only_list_27 = pop_only_list[2601:2700]
pop_only_list_28 = pop_only_list[2701:2800]
pop_only_list_29 = pop_only_list[2801:2900]
pop_only_list_30 = pop_only_list[2901:3000]


# for i in range(30):
#     results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_ + i)

results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_1)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_2)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_3)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_4)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_5)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_6)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_7)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_8)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_9)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_10)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_11)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_12)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_13)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_14)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_15)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_16)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_17)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_18)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_19)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_20)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_21)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_22)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_23)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_24)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_25)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_26)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_27)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_28)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_29)
results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_30)
# Out:
# HTTP Error for POST to https://api.spotify.com/v1/playlists/0THAuat95RJGcS5TssbJSy/tracks returned 400 due to Error parsing JSON.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# C:\Python\Python39\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# C:\Python\Python39\lib\site-packages\requests\models.py in raise_for_status(self)
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.spotify.com/v1/playlists/0THAuat95RJGcS5TssbJSy/tracks
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-307-0917b32f66b9> in <module>
#      64 results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_26)
#      65 results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_27)
# ---> 66 results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_28)
#      67 results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_29)
#      68 results = sp.user_playlist_add_tracks(username, playlist_id, pop_only_list_30)
#
# C:\Python\Python39\lib\site-packages\spotipy\client.py in user_playlist_add_tracks(self, user, playlist_id, tracks, position)
#     833                 - position - the position to add the tracks
#     834         """
# --> 835         return self.playlist_add_items(playlist_id, tracks, position)
#     836
#     837     def user_playlist_replace_tracks(self, user, playlist_id, tracks):
#
# C:\Python\Python39\lib\site-packages\spotipy\client.py in playlist_add_items(self, playlist_id, items, position)
#    1023         plid = self._get_id("playlist", playlist_id)
#    1024         ftracks = [self._get_uri("track", tid) for tid in items]
# -> 1025         return self._post(
#    1026             "playlists/%s/tracks" % (plid),
#    1027             payload=ftracks,
#
# C:\Python\Python39\lib\site-packages\spotipy\client.py in _post(self, url, args, payload, **kwargs)
#     294         if args:
#     295             kwargs.update(args)
# --> 296         return self._internal_call("POST", url, payload, kwargs)
#     297
#     298     def _delete(self, url, args=None, payload=None, **kwargs):
#
# C:\Python\Python39\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     259                          method, url, response.status_code, msg)
#     260
# --> 261             raise SpotifyException(
#     262                 response.status_code,
#     263                 -1,
#
# SpotifyException: http status: 400, code:-1 - https://api.spotify.com/v1/playlists/0THAuat95RJGcS5TssbJSy/tracks:
#  Error parsing JSON., reason: None
